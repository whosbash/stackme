# %%
def invert_dict(input_dict):
    inverted_dict = {}
    for key, value in input_dict.items():
        if value not in inverted_dict:
            inverted_dict[value] = [key]
        else:
            inverted_dict[value].append(key)
    return inverted_dict

# %%
len(invert_dict(stacks))
# Out:
# 43

# %%
len(reduced_domains)
# Out:
# 27

# %%
reduced_domains = {
    'Data Science & AI': ['affine', 'ollama', 'anythingllm', 'qdrant'],
    'Data & Database Management': ['supabase', 'clickhouse', 'redis', 'redisinsight', 'pgvector', 'iceberg', 'minio', 'mysql', 'mariadb', 'baserow', 'postgres', 'mongodb'],
    'Web & Automation': ['firecrawl', 'weavite', 'n8n', 'dify', 'airflow', 'flowise', 'lowcoder', 'appsmith', 'nocobase', 'nocodb', 'tooljet'],
    'NLP & Chatbots': ['langflow', 'langfuse', 'quepasa', 'typebot', 'botpress', 'chatwoot', 'chatwoot_nestor'],
    'Monitoring & IT Infrastructure': ['monitor', 'uptimekuma', 'glpi', 'traefik'],
    'Machine Learning': ['woofed'],
    'Project Management & CRM': ['openproject', 'focalboard', 'zep', 'twentycrm', 'evolution', 'evolution_lite', 'krayincrm'],
    'Messaging & Communication': ['rabbitmq', 'transcrevezap', 'kafka', 'mattermost', 'ntfy'],
    'Web Development & CMS': ['wordpress', 'directus', 'strapi'],
    'API & Admin Tools': ['wuzapi', 'unoapi', 'yourls', 'pgadmin', 'phpadmin'],
    'Document & Knowledge Management': ['documenso', 'docuseal', 'stirlingpdf', 'formbricks', 'moodle', 'outline'],
    'Business Intelligence & Analytics': ['metabase'],
    'Container & Backend Services': ['portainer'],
    'Security & Password Management': ['vaultwarden'],
    'Scheduling & File Management': ['easyappointments', 'calcom', 'nextcloud'],
    'Social & Marketing': ['humhub', 'mautic'],
    'ERP & Enterprise Solutions': ['odoo'],
    'Location Services': ['traccar'],
    'Design & Prototyping': ['excalidraw'],
    'Authentication': ['whoami']
}

# %%
stacks={
    "affine": "Data Science",
    "clickhouse": "Data Storage",
    "firecrawl": "Web Scraping",
    "langflow": "Natural Language Processing",
    "monitor": "Monitoring",
    "ollama": "AI/ML",
    "quepasa": "Chatbot",
    "traefik": "Networking",
    "woofed": "Machine Learning",
    "airflow": "Workflow Automation",
    "dify": "Integration",
    "flowise": "Workflow Automation",
    "langfuse": "Natural Language Processing",
    "moodle": "Learning Management",
    "openproject": "Project Management",
    "rabbitmq": "Messaging",
    "transcrevezap": "Messaging",
    "wordpress": "Web Development",
    "anythingllm": "AI/ML",
    "directus": "Headless CMS",
    "focalboard": "Project Management",
    "lowcoder": "Low Code",
    "mysql": "Database",
    "outline": "Note Taking",
    "redis": "Data Storage",
    "twentycrm": "Customer Relationship Management",
    "wuzapi": "API Management",
    "appsmith": "Low Code",
    "documenso": "Document Management",
    "formbricks": "Forms",
    "mariadb": "Database",
    "n8n": "Automation",
    "pgadmin": "Database Management",
    "redisinsight": "Data Storage",
    "typebot": "Chatbot",
    "yourls": "URL Shortener",
    "baserow": "Database",
    "docuseal": "Document Management",
    "glpi": "IT Management",
    "mattermost": "Communication",
    "nextcloud": "File Management",
    "pgvector": "Data Storage",
    "stirlingpdf": "Document Management",
    "unoapi": "API Management",
    "zep": "Project Management",
    "botpress": "Chatbot",
    "easyappointments": "Scheduling",
    "humhub": "Social Network",
    "mautic": "Marketing Automation",
    "nocobase": "Low Code",
    "phpadmin": "Database Management",
    "strapi": "Headless CMS",
    "uptimekuma": "Monitoring",
    "calcom": "Scheduling",
    "evolution": "CRM",
    "iceberg": "Data Storage",
    "metabase": "Business Intelligence",
    "nocodb": "Low Code",
    "portainer": "Container Management",
    "supabase": "Backend-as-a-Service",
    "vaultwarden": "Password Management",
    "chatwoot": "Customer Support",
    "evolution_lite": "CRM",
    "kafka": "Messaging",
    "minio": "Data Storage",
    "ntfy": "Notification",
    "postgres": "Database",
    "tooljet": "Low Code",
    "weavite": "Web Scraping",
    "chatwoot_nestor": "Customer Support",
    "excalidraw": "Design",
    "krayincrm": "CRM",
    "mongodb": "Database",
    "odoo": "ERP",
    "qdrant": "AI/ML",
    "traccar": "GPS Tracking",
    "whoami": "Authentication"
}

reduced_domains = {
    'Infrastructure & Services': ['monitor', 'uptimekuma', 'glpi', 'traefik', 'vaultwarden', 'wuzapi', 'unoapi', 'yourls', 'portainer'],
    'Data Storage': ['supabase', 'clickhouse', 'redis', 'redisinsight', 'pgvector', 'iceberg', 'minio', 'mysql', 'mariadb', 'baserow', 'postgres', 'mongodb'],
    'Data Management': ['pgadmin', 'phpadmin'],
    'Analytics & BI': ['metabase'],
    'AI & NLP': ['affine', 'ollama', 'anythingllm', 'qdrant', 'woofed', 'langflow', 'langfuse'],
    'Messaging & Communication': ['rabbitmq', 'transcrevezap', 'kafka', 'quepasa', 'typebot', 'botpress', 'chatwoot', 'chatwoot_nestor', 'mattermost', 'ntfy'],
    'Project & Task Management': ['openproject', 'focalboard', 'zep', 'twentycrm', 'evolution', 'evolution_lite', 'krayincrm'],
    'Document & Content Management': ['documenso', 'docuseal', 'stirlingpdf', 'formbricks', 'moodle', 'outline'],
    'Web Development': ['wordpress', 'directus', 'strapi'],
    'Automation & Low-Code': ['firecrawl', 'weavite', 'n8n', 'dify', 'airflow', 'flowise', 'lowcoder', 'appsmith', 'nocobase', 'nocodb', 'tooljet'],
    'Scheduling & Collaboration': ['easyappointments', 'calcom', 'nextcloud'],
    'Social & Marketing': ['humhub', 'mautic'],
    'ERP & Enterprise Solutions': ['odoo'],
    'Location Services': ['traccar'],
    'Design & Prototyping': ['excalidraw'],
    'Authentication': ['whoami']
}

# Extract values into a list
stacks_values=list(stacks.values())

# Flatten it
stacks_values_flat = [item for sublist in stacks_values for item in sublist]

print(f"Flatten length: {len(stacks_values_flat)}")

# Flatten values into a set
stacks_from_domains=set()
for value in reduced_domains.values():
    stacks_from_domains.update(value)

stacks_values=set(stacks.keys())

stacks_values.difference(stacks_from_domains)
# Out:
# set()

# %%
stacks.values()
# Out:
# dict_values(['Data Science', 'Data Storage', 'Web Scraping', 'Natural Language Processing', 'Monitoring', 'AI/ML', 'Chatbot', 'Networking', 'Machine Learning', 'Workflow Automation', 'Integration', 'Workflow Automation', 'Natural Language Processing', 'Learning Management', 'Project Management', 'Messaging', 'Messaging', 'Web Development', 'AI/ML', 'Headless CMS', 'Project Management', 'Low Code', 'Database', 'Note Taking', 'Data Storage', 'Customer Relationship Management', 'API Management', 'Low Code', 'Document Management', 'Forms', 'Database', 'Automation', 'Database Management', 'Data Storage', 'Chatbot', 'URL Shortener', 'Database', 'Document Management', 'IT Management', 'Communication', 'File Management', 'Data Storage', 'Document Management', 'API Management', 'Project Management', 'Chatbot', 'Scheduling', 'Social Network', 'Marketing Automation', 'Low Code', 'Database Management', 'Headless CMS', 'Monitoring', 'Scheduling', 'CRM', 'Data Storage', 'Business Intelligence', 'L
# ...

# %%
from eule import euler

dependencies={
    "mysql": [
        "mautic", 
        "strapi", 
        "humhub", 
        "krayincrm", 
        "traccar", 
        "easyappointments", 
        "wordpress", 
        "yourls"
    ],
    "postgres": [
        "supabase", 
        "dify", 
        "airflow", 
        "n8n", 
        "chatwoot_nestor", 
        "chatwoot", 
        "woofed", 
        "evolution", 
        "evolution_lite", 
        "typebot", 
        "twentycrm", 
        "tooljet", 
        "formbricks", 
        "outline", 
        "documenso", 
        "calcom", 
        "affine", 
        "directus", 
        "nextcloud", 
        "zep", 
        "mattermost", 
        "docuseal", 
        "baserow", 
        "nocobase", 
        "flowise", 
        "openproject", 
        "metabase", 
        "wuzapi", 
        "langflow", 
        "langduse", 
        "botpress", 
        "nocodb", 
        "odoo"
    ],
    "pgvector": [
        "woofed", 
        "formbricks", 
        "zep", 
        "pgvector"
    ],
    "redis": [
        "dify", 
        "airflow", 
        "n8n", 
        "chatwoot_nestor", 
        "chatwoot", 
        "woofed", 
        "evolution", 
        "evolution_lite", 
        "firecrawl", 
        "lowcoder", 
        "twentycrm", 
        "tooljet", 
        "outline", 
        "humhub", 
        "krayincrm", 
        "unoapi", 
        "affine", 
        "directus", 
        "transcrevezap", 
        "nextcloud", 
        "baserow", 
        "wordpress", 
        "openproject", 
        "redisinsight", 
        "botpress"
    ],
    "mongodb": [ "lowcoder"],
    "mariadb": ["moodle"],
    "minio": ["supabase", "mautic", "lowcoder", "iceberg", "outline"],
    "qdrant": ["anythingllm"]
}

euler(dependencies)
# Out:
# {('pgvector',): ['pgvector'],
#  ('pgvector', 'postgres'): ['formbricks', 'zep'],
#  ('pgvector', 'postgres', 'redis'): ['woofed'],
#  ('postgres',): ['calcom',
#   'mattermost',
#   'langflow',
#   'flowise',
#   'docuseal',
#   'langduse',
#   'typebot',
#   'nocobase',
#   'wuzapi',
#   'metabase',
#   'nocodb',
#   'odoo',
#   'documenso'],
#  ('minio', 'postgres'): ['supabase'],
#  ('postgres', 'redis'): ['twentycrm',
#   'evolution_lite',
#   'chatwoot',
#   'directus',
#   'evolution',
#   'affine',
#   'chatwoot_nestor',
#   'airflow',
#   'openproject',
#   'nextcloud',
#   'dify',
#   'n8n',
#   'baserow',
#   'tooljet',
#   'botpress'],
#  ('minio', 'postgres', 'redis'): ['outline'],
#  ('minio', 'mongodb', 'redis'): ['lowcoder'],
#  ('redis',): ['firecrawl', 'redisinsight', 'transcrevezap', 'unoapi'],
#  ('mysql', 'redis'): ['krayincrm', 'humhub', 'wordpress'],
#  ('qdrant',): ['anythingllm'],
#  ('mariadb',): ['moodle'],
#  ('minio',): ['iceberg'],
# ...

# %%
def generate_custom_strings(size, separator, label):
    # Ensure that the label fits within the specified size
    label_prefix = "BEGIN OF "
    label_suffix = "END OF "
    max_label_size = size - len(label_prefix) - len(label_suffix) - 4  # Account for spaces and padding

    # If the label is too long, truncate it to fit
    truncated_label = label[:max_label_size] if len(label) > max_label_size else label

    # Calculate padding for centering
    begin_label = f"BEGIN OF {truncated_label}"
    end_label = f"END OF {truncated_label}"
    
    begin_padding = (size - len(begin_label)) // 2
    end_padding = (size - len(end_label)) // 2

    # Ensure padding is correct to avoid overflow
    begin_string = f"{separator * begin_padding} {begin_label} {separator * begin_padding}"
    end_string = f"{separator * end_padding} {end_label} {separator * end_padding}"

    return begin_string[:size], end_string[:size]


# Example usage
separator = "#"
size = 100  # Custom size for the string
labels = [
    "CONSTANTS",
    "GENERAL UTILITARY FUNCTIONS",
    "JSON-RELATED FUNCTIONS",
    "DISPLAY-RELATED FUNCTIONS",
    "VALIDATION-RELATED FUNCTION",
    "GENERAL DEPLOYMENT FUNCTIONS",
    "MENU UTILS",
    "DOCKER DEPLOYMENT UTILS",
    "PORTAINER DEPLOYMENT UTILS",
    "STACK DEPLOYMENT UTILITARY FUNCTIONS",
    "STACK DEPLOYMENT FUNCTIONS",
    "CONFIGURATION VARIABLE",
    "E-MAIL UTILS",
    "PROMPT UTILS",
    "COMPOSE FILES",
    "SETUP FUNCTIONS",
    "MENU DEFINITIONS",
]

for label in labels:
    begin_str, end_str = generate_custom_strings(size, separator, label)

    print(begin_str)
    print(end_str)
# Out:
# ######################################### BEGIN OF CONSTANTS #######################################
# ########################################## END OF CONSTANTS ########################################
# ################################ BEGIN OF GENERAL UTILITARY FUNCTIONS ##############################
# ################################# END OF GENERAL UTILITARY FUNCTIONS ###############################
# ################################## BEGIN OF JSON-RELATED FUNCTIONS #################################
# ################################### END OF JSON-RELATED FUNCTIONS ##################################
# ################################# BEGIN OF DISPLAY-RELATED FUNCTIONS ###############################
# ################################## END OF DISPLAY-RELATED FUNCTIONS ################################
# ################################ BEGIN OF VALIDATION-RELATED FUNCTION ##############################
# ...
